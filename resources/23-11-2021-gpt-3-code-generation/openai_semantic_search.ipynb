# %%
import pandas as pd
import dotenv
import openai
import os
from functools import lru_cache


pd.options.display.max_colwidth = 300

# %%
titles = (
    "The Dark Knight",
    "Forrest Gump",
    "Interstellar",
    "Joker",
    "Lion King",
    "Lord Of The Rings",
    "The Good, The Bad And The Ugly",
    "WALL-E",
)

# %%
plots = (
    "When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.",
    "The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.",
    "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
    "In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.",
    "Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.",
    "A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.",
    "A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.",
    "In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.",
)

# %%
df = pd.DataFrame({
    'titles': titles,
    'plots': plots,
})

# %%
df
# Out:
#                            titles  \
# 0                 The Dark Knight
# 1                    Forrest Gump
# 2                    Interstellar
# 3                           Joker
# 4                       Lion King
# 5               Lord Of The Rings
# 6  The Good, The Bad And The Ugly
# 7                          WALL-E
#
#                                                                                                                                                                                                                                             plots
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.

# %%
dotenv.load_dotenv(override=True)
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
response = openai.Engine("babbage").search(
    documents=plots, 
    query="adventure",
    max_rerank=None,
    return_metadata=True
)

scores = [x["score"] for x in response["data"]]

df_scores = pd.DataFrame({
    'scores': scores,
    'titles': titles,
    'plots': plots,
})

df_scores.sort_values(by='scores', ascending=False)
# Out:
#     scores                          titles  \
# 2  185.965                    Interstellar
# 6  180.275  The Good, The Bad And The Ugly
# 5  150.810               Lord Of The Rings
# 0  122.569                 The Dark Knight
# 7  119.448                          WALL-E
# 3   56.531                           Joker
# 1  -23.050                    Forrest Gump
# 4  -47.036                       Lion King
#
#                                                                                                                                                                                                                                             plots
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.

# %%
@lru_cache
def search(docs, query, engine):
    response = openai.Engine(engine).search(
        documents=docs, 
        query=query,
        max_rerank=None,
        return_metadata=True
    )

    scores = [x["score"] for x in response["data"]]

    df_scores = pd.DataFrame({
        'scores': scores,
        'titles': titles,
        'plots': plots,
    })
    
    return df_scores.sort_values(by='scores', ascending=False)

# %%
search(docs=plots, query="galactic adventure", engine="babbage")
# Out:
#     scores                          titles  \
# 2  259.200                    Interstellar
# 7  188.776                          WALL-E
# 5   34.088               Lord Of The Rings
# 6   19.175  The Good, The Bad And The Ugly
# 1  -12.365                    Forrest Gump
# 4  -49.809                       Lion King
# 3  -64.257                           Joker
# 0  -82.443                 The Dark Knight
#
#                                                                                                                                                                                                                                             plots
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.

# %%
search(docs=plots, query="galaactic adventure", engine="babbage")
# Out:
#     scores                          titles  \
# 2  107.603                    Interstellar
# 7   87.682                          WALL-E
# 4   31.309                       Lion King
# 5   28.943               Lord Of The Rings
# 0   26.244                 The Dark Knight
# 6   11.669  The Good, The Bad And The Ugly
# 3  -43.274                           Joker
# 1  -45.756                    Forrest Gump
#
#                                                                                                                                                                                                                                             plots
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.

# %%
search(docs=plots, query="anti-hero", engine="babbage")
# Out:
#     scores                          titles  \
# 3  130.946                           Joker
# 0   87.648                 The Dark Knight
# 7   42.010                          WALL-E
# 2   37.668                    Interstellar
# 5   24.527               Lord Of The Rings
# 6   22.588  The Good, The Bad And The Ugly
# 4  -12.573                       Lion King
# 1  -13.527                    Forrest Gump
#
#                                                                                                                                                                                                                                             plots
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.

# %%
search(docs=plots, query="Joker is main antagonist", engine="babbage")
# Out:
#     scores                          titles  \
# 0  265.829                 The Dark Knight
# 3  226.638                           Joker
# 7  -22.065                          WALL-E
# 5  -35.247               Lord Of The Rings
# 1  -43.656                    Forrest Gump
# 2  -55.604                    Interstellar
# 4  -63.859                       Lion King
# 6  -71.818  The Good, The Bad And The Ugly
#
#                                                                                                                                                                                                                                             plots
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.

# %%
search(docs=plots, query="Joker is main protagonist", engine="babbage")
# Out:
#     scores                          titles  \
# 3  216.574                           Joker
# 0  211.972                 The Dark Knight
# 7    9.720                          WALL-E
# 1  -17.991                    Forrest Gump
# 2  -28.326                    Interstellar
# 5  -29.267               Lord Of The Rings
# 6  -54.270  The Good, The Bad And The Ugly
# 4  -79.269                       Lion King
#
#                                                                                                                                                                                                                                             plots
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.

# %%
search(docs=plots, query="animation", engine="babbage")
# Out:
#     scores                          titles  \
# 7  180.000                          WALL-E
# 3  124.845                           Joker
# 4  122.048                       Lion King
# 0   20.283                 The Dark Knight
# 2   -7.914                    Interstellar
# 5  -16.816               Lord Of The Rings
# 1  -34.538                    Forrest Gump
# 6 -132.378  The Good, The Bad And The Ugly
#
#                                                                                                                                                                                                                                             plots
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.

# %%
search(docs=plots, query="Peter Jackson", engine="babbage")
# Out:
#     scores                          titles  \
# 5  412.042               Lord Of The Rings
# 2  157.149                    Interstellar
# 7  116.005                          WALL-E
# 4   74.175                       Lion King
# 3   60.253                           Joker
# 6   60.018  The Good, The Bad And The Ugly
# 0   48.990                 The Dark Knight
# 1  -27.514                    Forrest Gump
#
#                                                                                                                                                                                                                                             plots
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.

# %%
search(docs=plots, query="David Lynch", engine="babbage")
# Out:
#     scores                          titles  \
# 3  103.515                           Joker
# 7   67.028                          WALL-E
# 0   48.821                 The Dark Knight
# 1   47.389                    Forrest Gump
# 2   31.612                    Interstellar
# 6   20.505  The Good, The Bad And The Ugly
# 5  -50.152               Lord Of The Rings
# 4  -78.550                       Lion King
#
#                                                                                                                                                                                                                                             plots
# 3         In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.
# 7                                                                                                 In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# 0                                                   When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 1  The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.
# 2                                                                                                                                             A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.
# 6                                                                                                      A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# 5                                                                                        A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# 4                                                                                                                                      Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.

# %%
search(docs=plots, query="a"*8000, engine="ada")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /tmp/ipykernel_14590/2837132667.py in <module>
# ----> 1 search(docs=plots, query="a"*8000, engine="ada")
#
# /tmp/ipykernel_14590/3212417239.py in search(docs, query, engine)
#       1 @lru_cache
#       2 def search(docs, query, engine):
# ----> 3     response = openai.Engine(engine).search(
#       4         documents=docs,
#       5         query=query,
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/openai/api_resources/engine.py in search(self, **params)
#      27
#      28     def search(self, **params):
# ---> 29         return self.request("post", self.instance_url() + "/search", params)
#      30
#      31     def embeddings(self, **params):
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/openai/openai_object.py in request(self, method, url, params, headers, stream, plain_old_data, request_id)
#     168             organization=self.organization,
#     169         )
# --> 170         response, stream, api_key = requestor.request(
#     171             method, url, params, stream=stream, headers=headers, request_id=request_id
#     172         )
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id)
#     105             request_id=request_id,
#     106         )
# --> 107         resp, got_stream = self._interpret_response(result, stream)
#     108         return resp, got_stream, self.api_key
#     109
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     290         else:
#     291             return (
# --> 292                 self._interpret_response_line(
#     293                     result.content, result.status_code, result.headers, stream=False
#     294                 ),
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     316         stream_error = stream and "error" in resp.data
#     317         if stream_error or not 200 <= rcode < 300:
# --> 318             raise self.handle_error_response(
#     319                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     320             )
#
# InvalidRequestError: The document at index 1 is 1 tokens over the length limit of 35.
